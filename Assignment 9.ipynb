# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
train = pd.read_csv('D:/Projects/Leaf Classification/train.csv')
test = pd.read_csv('D:/Projects/Leaf Classification/test.csv')

# %%
test.head()
# Out:
#    id   margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 0   4  0.019531  0.009766  0.078125  0.011719  0.003906  0.015625  0.005859
# 1   7  0.007812  0.005859  0.064453  0.009766  0.003906  0.013672  0.007812
# 2   9  0.000000  0.000000  0.001953  0.021484  0.041016  0.000000  0.023438
# 3  12  0.000000  0.000000  0.009766  0.011719  0.017578  0.000000  0.003906
# 4  13  0.001953  0.000000  0.015625  0.009766  0.039062  0.000000  0.009766
#
#    margin8   margin9  ...  texture55  texture56  texture57  texture58  \
# 0      0.0  0.005859  ...   0.006836   0.000000   0.015625   0.000977
# 1      0.0  0.033203  ...   0.000000   0.000000   0.006836   0.001953
# 2      0.0  0.011719  ...   0.128910   0.000000   0.000977   0.000000
# 3      0.0  0.003906  ...   0.012695   0.015625   0.002930   0.036133
# 4      0.0  0.005859  ...   0.000000   0.042969   0.016602   0.010742
#
#    texture59  texture60  texture61  texture62  texture63  texture64
# ...

# %%
train.head()
# Out:
#    id                species   margin1   margin2   margin3   margin4  \
# 0   1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1   2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2   3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3   5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4   6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
#
#     margin5   margin6   margin7  margin8  ...  texture55  texture56  \
# 0  0.011719  0.009766  0.027344      0.0  ...   0.007812   0.000000
# 1  0.025391  0.001953  0.019531      0.0  ...   0.000977   0.000000
# 2  0.003906  0.005859  0.068359      0.0  ...   0.154300   0.000000
# 3  0.021484  0.019531  0.023438      0.0  ...   0.000000   0.000977
# 4  0.013672  0.015625  0.005859      0.0  ...   0.096680   0.000000
#
#    texture57  texture58  texture59  texture60  texture61  texture62  \
# 0   0.002930   0.002930   0.035156        0.0        0.0   0.004883
# ...

# %%
train.isnull().sum()
# Out:
# id           0
# species      0
# margin1      0
# margin2      0
# margin3      0
#             ..
# texture60    0
# texture61    0
# texture62    0
# texture63    0
# texture64    0
# Length: 194, dtype: int64

# %%
train.columns
# Out:
# Index(['id', 'species', 'margin1', 'margin2', 'margin3', 'margin4', 'margin5',
#        'margin6', 'margin7', 'margin8',
#        ...
#        'texture55', 'texture56', 'texture57', 'texture58', 'texture59',
#        'texture60', 'texture61', 'texture62', 'texture63', 'texture64'],
#       dtype='object', length=194)

# %%
train.duplicated().sum()
# Out:
# 0

# %%
train.info
# Out:
# <bound method DataFrame.info of        id                species   margin1   margin2   margin3   margin4  \
# 0       1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1       2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2       3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3       5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4       6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
# ..    ...                    ...       ...       ...       ...       ...
# 985  1575   Magnolia_Salicifolia  0.060547  0.119140  0.007812  0.003906
# 986  1578            Acer_Pictum  0.001953  0.003906  0.021484  0.107420
# 987  1581     Alnus_Maximowiczii  0.001953  0.003906  0.000000  0.021484
# 988  1582          Quercus_Rubra  0.000000  0.000000  0.046875  0.056641
# 989  1584         Quercus_Afares  0.023438  0.019531  0.031250  0.015625
#
# ...

# %%
train['species'].value_counts()
# Out:
# Liquidambar_Styraciflua        10
# Salix_Intergra                 10
# Cotinus_Coggygria              10
# Quercus_Rubra                  10
# Quercus_Rhysophylla            10
#                                ..
# Rhododendron_x_Russellianum    10
# Quercus_Phillyraeoides         10
# Alnus_Sieboldiana              10
# Betula_Austrosinensis          10
# Salix_Fragilis                 10
# Name: species, Length: 99, dtype: int64

# %%
train2 = train
train2 = train2.drop(['species'], axis = 1)

# %%
species = train['species']

# %%
train2.insert(0, 'species', species)

# %%
train2.head()
# Out:
#                  species  id   margin1   margin2   margin3   margin4  \
# 0            Acer_Opalus   1  0.007812  0.023438  0.023438  0.003906
# 1  Pterocarya_Stenoptera   2  0.005859  0.000000  0.031250  0.015625
# 2   Quercus_Hartwissiana   3  0.005859  0.009766  0.019531  0.007812
# 3        Tilia_Tomentosa   5  0.000000  0.003906  0.023438  0.005859
# 4     Quercus_Variabilis   6  0.005859  0.003906  0.048828  0.009766
#
#     margin5   margin6   margin7  margin8  ...  texture55  texture56  \
# 0  0.011719  0.009766  0.027344      0.0  ...   0.007812   0.000000
# 1  0.025391  0.001953  0.019531      0.0  ...   0.000977   0.000000
# 2  0.003906  0.005859  0.068359      0.0  ...   0.154300   0.000000
# 3  0.021484  0.019531  0.023438      0.0  ...   0.000000   0.000977
# 4  0.013672  0.015625  0.005859      0.0  ...   0.096680   0.000000
#
#    texture57  texture58  texture59  texture60  texture61  texture62  \
# 0   0.002930   0.002930   0.035156        0.0        0.0   0.004883
# ...

# %%
test.head()
# Out:
#    id   margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 0   4  0.019531  0.009766  0.078125  0.011719  0.003906  0.015625  0.005859
# 1   7  0.007812  0.005859  0.064453  0.009766  0.003906  0.013672  0.007812
# 2   9  0.000000  0.000000  0.001953  0.021484  0.041016  0.000000  0.023438
# 3  12  0.000000  0.000000  0.009766  0.011719  0.017578  0.000000  0.003906
# 4  13  0.001953  0.000000  0.015625  0.009766  0.039062  0.000000  0.009766
#
#    margin8   margin9  ...  texture55  texture56  texture57  texture58  \
# 0      0.0  0.005859  ...   0.006836   0.000000   0.015625   0.000977
# 1      0.0  0.033203  ...   0.000000   0.000000   0.006836   0.001953
# 2      0.0  0.011719  ...   0.128910   0.000000   0.000977   0.000000
# 3      0.0  0.003906  ...   0.012695   0.015625   0.002930   0.036133
# 4      0.0  0.005859  ...   0.000000   0.042969   0.016602   0.010742
#
#    texture59  texture60  texture61  texture62  texture63  texture64
# ...

# %%
X = train2.iloc[:, 1:]
Y = train2.iloc[:, 0]

# %% [markdown]
# # Before implementing on the test dataset, lets test our models accuracy

# %%
# Splitting the data
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(X,Y,test_size = (0.3))

# %% [markdown]
# # Lets implement Naive Bayes.

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
predNB = gnb.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, predNB)
# Out:
# 0.9259259259259259

# %% [markdown]
# # Now lets implement the algorithm on our test dataset.

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X, Y)
# Out:
# GaussianNB()

# %%
predNB = gnb.predict(test)

# %% [markdown]
# # Let's explore the predictions

# %%
predNB
# Out:
# array(['Quercus_Agrifolia', 'Quercus_Afares', 'Acer_Circinatum',
#        'Castanea_Sativa', 'Alnus_Viridis', 'Quercus_x_Hispanica',
#        'Acer_Opalus', 'Eucalyptus_Glaucescens', 'Quercus_Variabilis',
#        'Acer_Rufinerve', 'Phildelphus', 'Quercus_Pontica',
#        'Quercus_Pubescens', 'Alnus_Cordata', 'Quercus_Alnifolia',
#        'Quercus_Crassifolia', 'Populus_Grandidentata',
#        'Quercus_Phillyraeoides', 'Alnus_Sieboldiana', 'Quercus_Palustris',
#        'Quercus_Crassipes', 'Quercus_Infectoria_sub',
#        'Quercus_Chrysolepis', 'Quercus_Rhysophylla', 'Acer_Circinatum',
#        'Quercus_Nigra', 'Eucalyptus_Glaucescens', 'Arundinaria_Simonii',
#        'Liquidambar_Styraciflua', 'Quercus_Nigra', 'Quercus_Brantii',
#        'Quercus_Pontica', 'Prunus_Avium', 'Quercus_Afares',
#        'Acer_Palmatum', 'Liriodendron_Tulipifera', 'Alnus_Viridis',
#        'Quercus_Castaneifolia', 'Magnolia_Salicifolia',
# ...
